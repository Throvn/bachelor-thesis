# %%
from torchviz import make_dot
import torch
from model import SingleInputLSTMClassifier
from preparation import create_sequences
from balance import grouped_test

# %%
observation = grouped_test.iloc[0]
X_seq, y_seq = create_sequences(observation, 64)
X = torch.tensor(X_seq.squeeze().squeeze(), dtype=torch.float32)
X = torch.nan_to_num(X, nan=0.0)
model = SingleInputLSTMClassifier(3, isBidirectional=False)
make_dot(model(X), params=dict(list(model.named_parameters())))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 6
#       4 X = torch.nan_to_num(X, nan=0.0)
#       5 model = SingleInputLSTMClassifier(3, isBidirectional=False)
# ----> 6 make_dot(model(X), params=dict(list(model.named_parameters())))
#
# File ~/Documents/is-dao-active/model/venv/lib/python3.12/site-packages/IPython/core/displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File ~/Documents/is-dao-active/model/venv/lib/python3.12/site-packages/IPython/core/displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
# ...

# %%
graph.render("rnn_torchviz", format="png", engine='dot')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 graph.render("rnn_torchviz", format="png", engine='dot')
#
# File ~/Documents/is-dao-active/model/venv/lib/python3.12/site-packages/graphviz/_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# ...

# %%
X = torch.randn([1, 2, 3])
make_dot(model(X), params=dict(model.named_parameters()))
